# %% [markdown]
# <a href="https://colab.research.google.com/github/wenyanglyu/TextMining1/blob/main/TextMining1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
import nltk
from collections import Counter


# Mount Google Drive
drive.mount('/content/drive')

# Navigate to the folder containing your data
folder_path = "/content/drive/My Drive/TextMining/terrorismData"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read the files and extract them into a list
TerrorismList = []
for filename in os.listdir(folder_path):
  if filename.endswith('.txt'):  # Filter for text files
    file_path = os.path.join(folder_path, filename)
    with open(file_path, 'r') as f:
      data = f.read()
      TerrorismList.append(data)
print(f"This folder has totally {len(TerrorismList)} text files")
# Out:
# This folder has totally 1791 text files

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
try:
    tokensTerrorismList = []
    for i in range(len(TerrorismList)):
        tokensTerrorismList.append(nltk.word_tokenize(TerrorismList[i]))
except Exception as e:
    print(f"An error occurred: {e}")

print(f"The first file has is 784 words according to its description, and it's contents are: \n")
print(TerrorismList[0])
print(f"Its tokenized file has {len(tokensTerrorismList[0])} words, and it's contents are: \n")
print(tokensTerrorismList[0])
# Out:
# The first file has is 784 words according to its description, and it's contents are:
#
# "On Super Tuesday, two commentators on CNN argued about the Ku Klux Klan. On television. In America. In 2016.
# It was a singular moment in cable news. This is partly because, until this week, the K.K.K.'s loathsomeness had seemed to be a settled issue. But also because -- as intense and unsettling as the argument was -- it was substantive and illuminating in a way time-killing cable shouting matches rarely are.
# The exchange began when the conservative commentator S. E. Cupp criticized the Republican front-runner, Donald J. Trump, for the \"dog whistle\" racial implications of his comments and proposals. (He has, besides denigrating Mexican immigrants and calling for a ban on Muslims entering the country, said that he's not sure whether he would have opposed internment camps for Japanese-Americans during World War II.)
# ...

# %%
# Remove Stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words_NLTK = set(stopwords.words('english'))

import string
# Define the set of punctuation characters
punctuation_set = set(string.punctuation)

# Remove punctuation and numbers, convert to lowercase, and then remove stopwords
removeStopWords = []
for tokens in tokensTerrorismList:
    # Remove punctuation and numbers, and convert to lowercase
    cleaned_tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in punctuation_set]
    # Remove stopwords
    remove = [word for word in cleaned_tokens if word not in stop_words_NLTK]
    removeStopWords.append(remove)



print(f"After remove stopwords and punctuation and numbers, the first file only has {len(removeStopWords[0])} now\n")
print(removeStopWords[0])

# Remove Stopwords for tokensTerrorismList; if you don't want to remove, just comment it out
tokensTerrorismList = removeStopWords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# After remove stopwords and punctuation and numbers, the first file only has 402 now
#
# ...

# %%
# extract bigrams
def find_bigrams(input_list):
  bigram_list = []
  for i in range(len(input_list)-1):
      bigram_list.append((input_list[i], input_list[i+1]))
  return bigram_list
#get individual items from the bigram


bigramsTerrorismList = []

# Iterate over tokensTerrorismList
for tokens in tokensTerrorismList:
    # Find bigrams for the current list of tokens
    bigrams = find_bigrams(tokens)
    # Append the bigrams to bigramsTerrorismList
    bigramsTerrorismList.append(bigrams)
print(tokensTerrorismList[0])
print(bigramsTerrorismList[0])
print(f"file 1 has {len(tokensTerrorismList[0])} tokens and {len(bigramsTerrorismList[0])} bigrams")
# Out:
# ['super', 'tuesday', 'two', 'commentators', 'cnn', 'argued', 'ku', 'klux', 'klan', 'television', 'america', 'singular', 'moment', 'cable', 'news', 'partly', 'week', 'loathsomeness', 'seemed', 'settled', 'issue', 'also', 'intense', 'unsettling', 'argument', 'substantive', 'illuminating', 'way', 'cable', 'shouting', 'matches', 'rarely', 'exchange', 'began', 'conservative', 'commentator', 'cupp', 'criticized', 'republican', 'donald', 'trump', 'dog', 'racial', 'implications', 'comments', 'proposals', 'besides', 'denigrating', 'mexican', 'immigrants', 'calling', 'ban', 'muslims', 'entering', 'country', 'said', 'sure', 'whether', 'would', 'opposed', 'internment', 'camps', 'world', 'war', 'ii', 'video', 'van', 'jones', 'jeffrey', 'lord', 'clash', 'donald', 'trump', 'watch', 'youtube', 'conversation', 'moved', 'perhaps', 'inevitably', 'trump', 'interview', 'sunday', 'cnn', 'jake', 'tapper', 'immediately', 'denounce', 'david', 'duke', 'former', 'klan', 'leader', 'supports', 'jeffrey', 'lord',
# ...

# %%
#count and sort objects
from collections import Counter

counters_list = []
for tokens in tokensTerrorismList:
  object_counts = Counter(tokens)
  counters_list.append(object_counts)
print(f"file 1 has {len(counters_list[0])} unique types, they are: \n {counters_list[0]}")
# Out:
# file 1 has 297 unique types, they are:
# ...

# %%
# stem extraction
from nltk.stem import PorterStemmer

stemmer= PorterStemmer()
stemTerrorismList = []
for tokens in tokensTerrorismList:
  stemTokens = []
  for words in tokens:
    stemWords = stemmer.stem(words)
    stemTokens.append(stemWords)
  stemTerrorismList.append(stemTokens)
print(len(stemTerrorismList))
print(f"file 1 has {len(stemTerrorismList[0])} stems, which are \n: {(stemTerrorismList[0])}")
# Out:
# 1791
# file 1 has 402 stems, which are
# ...

# %%
# lemma extraction
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
lemmatizer=WordNetLemmatizer()

lemmaTerrorismList = []
for tokens in tokensTerrorismList:
  lemmaTokens = []
  for words in tokens:
    lemmaWords = lemmatizer.lemmatize(words)
    lemmaTokens.append(lemmaWords)
  lemmaTerrorismList.append(lemmaTokens)
print(len(lemmaTerrorismList))
print(f"file 1 has {len(lemmaTerrorismList[0])} lemmas, which are \n: {(lemmaTerrorismList[0])}")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 1791
# file 1 has 402 stems, which are
# ...

# %%
# Store the trigram in the list
from nltk import ngrams
n = 3

# ngrams was stored in zip format
gramList = []
for textList in tokensTerrorismList:
    # convert list into string to use split()
    temList = ngrams(' '.join(textList).split(), n)
    gramList.append(temList)

print(gramList)
print("\n all the gramList are stored in zip format, need to extract every zip to a sublist\n")

triGramTerrorismList = []
for grams_list in gramList:
    sub_ngrams = []
    for grams in grams_list:
        sub_ngrams.append(grams)
    triGramTerrorismList.append(sub_ngrams)

print(triGramTerrorismList[0])
print(triGramTerrorismList[1])
# Out:
# [<zip object at 0x79095651a280>, <zip object at 0x79095643fcc0>, <zip object at 0x79083b9e7880>, <zip object at 0x790926004e00>, <zip object at 0x7908c25b5180>, <zip object at 0x7909539168c0>, <zip object at 0x790953789f40>, <zip object at 0x790957ebfac0>, <zip object at 0x79095356ec40>, <zip object at 0x7909531c6ac0>, <zip object at 0x79095314df40>, <zip object at 0x790952ee9040>, <zip object at 0x790952be40c0>, <zip object at 0x79088aabc880>, <zip object at 0x79094cbf9400>, <zip object at 0x790926070480>, <zip object at 0x79094c7a2080>, <zip object at 0x79094c684b00>, <zip object at 0x79094c76c700>, <zip object at 0x79094c546440>, <zip object at 0x79094fe90e80>, <zip object at 0x79094c0a8780>, <zip object at 0x79094c145900>, <zip object at 0x790947ca9840>, <zip object at 0x790947b51d40>, <zip object at 0x790947a32e00>, <zip object at 0x7909479a2700>, <zip object at 0x790947679c00>, <zip object at 0x79094752ec80>, <zip object at 0x790947489d40>, <zip object at 0x7909612f3700>, <zip 
# ...

# %%
# find out the most common trigram
from collections import Counter

triCounterTerrorismList = []
for list in triGramTerrorismList:
  trigram_counts = Counter(list)
  triCounterTerrorismList.append(trigram_counts)

mostTriCounter = []
for list in triCounterTerrorismList:
  most_common_trigram = list.most_common(1)[0][0]
  mostTriCounter.append(most_common_trigram)

for i in range(10):
  print(f"Text{i}:{mostTriCounter[i]}")

print(mostTriCounter)

mostOfMostTriCounter = Counter(mostTriCounter).most_common(1)[0][0]
print(f"\n The most common triCounter is {mostOfMostTriCounter}, well, I am suprised and then understood!")
# Out:
# Text0:('ku', 'klux', 'klan')
# Text1:('afghan', 'security', 'forces')
# Text2:('isis', 'means', 'islam')
# Text3:('undercover', 'agent', 'testified')
# Text4:('ku', 'klux', 'klan')
# Text5:('san', 'bernardino', 'case')
# Text6:('spanish', 'authorities', 'thursday')
# Text7:('word', 'count', 'copyright')
# Text8:('boko', 'haram', 'fighters')
# Text9:('six', 'nuns', 'plus')
# ...

# %%
# find out the two most common bigram, this time we put all bigram IN THE SAME LIST
from collections import Counter

bigram_counts = []
for list in bigramsTerrorismList:
  sub_bigram_counts = Counter(list)
  bigram_counts.append(sub_bigram_counts)

mostBiCounter = []
for list in bigram_counts:
  most_common_bigram = list.most_common(1)[0][0]
  mostBiCounter.append(most_common_bigram)


print(len(mostBiCounter))
print(mostBiCounter)
mostOfMostBiCounter = Counter(mostBiCounter).most_common(1)[0][0]
print(f"\n The most common biCounter of all files are {mostOfMostBiCounter}")
# Out:
# 1791
# ...

# %%
# Extract list of the four ngrams
from nltk import ngrams
n = 4

# ngrams was stored in zip format
gramList = []
for textList in tokensTerrorismList:
    # convert list into string to use split()
    temList = ngrams(' '.join(textList).split(), n)
    gramList.append(temList)

print(gramList)
print("\n all the gramList are stored in zip format, need to extract every zip to a sublist\n")

fourGramTerrorismList = []
for grams_list in gramList:
    sub_ngrams = []
    for grams in grams_list:
        sub_ngrams.append(grams)
    fourGramTerrorismList.append(sub_ngrams)

print(fourGramTerrorismList[0])
# Out:
# [<zip object at 0x790924036d40>, <zip object at 0x7909240590c0>, <zip object at 0x790924093b40>, <zip object at 0x7909240722c0>, <zip object at 0x7909240c7640>, <zip object at 0x79092220a800>, <zip object at 0x79092222d140>, <zip object at 0x79092222d480>, <zip object at 0x790922257dc0>, <zip object at 0x79092228bac0>, <zip object at 0x7909222aef00>, <zip object at 0x7909222e7cc0>, <zip object at 0x790924b0aec0>, <zip object at 0x790924b316c0>, <zip object at 0x790924b66480>, <zip object at 0x790924b7da80>, <zip object at 0x790924bc22c0>, <zip object at 0x790924bd5bc0>, <zip object at 0x790924bf1940>, <zip object at 0x79092771e700>, <zip object at 0x790927770fc0>, <zip object at 0x790927797900>, <zip object at 0x7909277b66c0>, <zip object at 0x7909277f3240>, <zip object at 0x7909236064c0>, <zip object at 0x790923634240>, <zip object at 0x79092364cc40>, <zip object at 0x79092369a880>, <zip object at 0x7909236a6ac0>, <zip object at 0x7909236e1880>, <zip object at 0x7909236f8d80>, <zip 
# ...

# %%
# Find 4-grams containing both bigrams
most_common_bigram1 = mostBiCounter[0]
most_common_bigram2 = mostBiCounter[1]

setBigram1 = set(most_common_bigram1)
setBigram2 = set(most_common_bigram2)

print(f"The below numbers are total files, tokens, biGrams, triGrams, fourGrams")
print(len(fourGramTerrorismList))
print(len(tokensTerrorismList[0]))
print(len(bigramsTerrorismList[0]))
print(len(triGramTerrorismList[0]))
print(len(fourGramTerrorismList[0]))


fourContainBiList = []
for sublist in fourGramTerrorismList:
  for subtuple in sublist:
    setSubTuple = set(subtuple)
    if setBigram1.issubset(setSubTuple) or setBigram2.issubset(setSubTuple):
        fourContainBiList.append(setSubTuple)

print(f"\n There are {len(fourContainBiList)} fourGrams containing the most two common biGrams \n {most_common_bigram1} \n {most_common_bigram2}")
print("\n These fourGrams are: \n")
print(fourContainBiList)
# Out:
# The below numbers are total files, tokens, biGrams, triGrams, fourGrams
# 1791
# 402
# 401
# 400
# 399
#
#  There are 88 fourGrams containing the most two common biGrams
#  ('ku', 'klux')
#  ('general', 'campbell')
#
#  These fourGrams are:
#
# ...
